# %% [markdown]
# # 03 — Model Training & Evaluation
#
# Train the LightGBM demand forecasting model, compare against the baseline, and evaluate calibration and uncertainty estimates.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from model.baseline import BaselineModel
from model.features import build_feature_matrix
from model.calibrate import DemandCalibrator
from model.uncertainty import ConformalPredictor

# %matplotlib inline

# %%
# Train the baseline
# df = pd.read_csv('../data/raw/swap_events.csv', parse_dates=['timestamp'])
# baseline = BaselineModel().fit(df)
# baseline_preds = baseline.predict(df)

# %%
# Run full training pipeline
# from model.train import train
# train(data_path='../data/processed/features.parquet')

# %%
# Calibration
# cal = DemandCalibrator()
# cal.fit(raw_preds, actuals)
# ece = cal.expected_calibration_error(cal.transform(raw_preds), actuals)
# print(f'ECE: {ece:.4f}')

# %%
# Conformal prediction intervals
# cp = ConformalPredictor(model, alpha=0.1)
# cp.calibrate(X_cal, y_cal)
# point, lower, upper = cp.predict_interval(X_test)
