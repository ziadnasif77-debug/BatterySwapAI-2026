# %% [markdown]
# # 02 — Feature Engineering
#
# Build and validate the feature matrix: calendar features, lag features, rolling statistics, and correlation analysis.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from model.features import add_calendar_features, add_lag_features, add_rolling_features, build_feature_matrix

# %matplotlib inline
sns.set_theme(style='whitegrid')

# %%
# df = pd.read_csv('../data/raw/swap_events.csv', parse_dates=['timestamp'])
# df = add_calendar_features(df)
# df.head()

# %%
# Lag feature check
# df = add_lag_features(df, 'swap_count', lags=[1, 2, 3, 6, 12, 24])
# df[['station_id','timestamp','swap_count','swap_count_lag_1','swap_count_lag_24']].head(30)

# %%
# Correlation heatmap
# X, y = build_feature_matrix(df)
# corr = X.corrwith(y).sort_values(ascending=False)
# corr.plot(kind='barh', figsize=(8, 10), title='Feature correlation with swap_count')
# plt.tight_layout()
